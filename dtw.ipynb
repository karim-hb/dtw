# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

from glob import glob

import librosa
import librosa.display
import IPython.display as ipd
from fastdtw import fastdtw

# %%
audio_files = glob('./lastname/*.wav')

# %%
ipd.Audio(audio_files[1])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def calculate_dtw_distance(feature1, feature2):
    distance, _ = fastdtw(feature1.T, feature2.T)
    return distance

# %%
last_name_features_list = []
for i in range(13):
    y, sr = librosa.load(audio_files[i])
    y_trimmed, _ = librosa.effects.trim(y, top_db=20)
    last_name_features_list.append(y_trimmed)

# %%
for i in range(10):
    for j in range(i+1, 10):
        
        distance = calculate_dtw_distance(last_name_features_list[i], last_name_features_list[j])
        print(f"Distance between last_name_record_{i}.wav and last_name_record_{j}.wav: {distance}")
# Out:
# Distance between last_name_record_0.wav and last_name_record_1.wav: 473.1625353427298
# Distance between last_name_record_0.wav and last_name_record_2.wav: 309.6203120385471
# Distance between last_name_record_0.wav and last_name_record_3.wav: 1206.2090035176952
# Distance between last_name_record_0.wav and last_name_record_4.wav: 981.4776243352535
# Distance between last_name_record_0.wav and last_name_record_5.wav: 350.15580211627093
# Distance between last_name_record_0.wav and last_name_record_6.wav: 500.95547961755074
# Distance between last_name_record_0.wav and last_name_record_7.wav: 547.035268096748
# Distance between last_name_record_0.wav and last_name_record_8.wav: 575.1663233349464
# Distance between last_name_record_0.wav and last_name_record_9.wav: 730.2643643256215
# Distance between last_name_record_1.wav and last_name_record_2.wav: 520.9645885654681
# Distance between last_name_record_1.wav and last_name_record_3.wav: 1139.321311588159
# Distance between last_name_record_1.wav and last_name_record_4.wav: 965.7228954879902
# Distance between last_name_record_1.wav and last_name_record_5.wav: 454.93489471766225
# Distance between last_name_record_1.wav and last_name_record_6.wav: 530.1809729403685
# Distance between last_name_record_1.wav and last_name_record_7.wav: 646.492479939734
# Distance between last_name_record_1.wav and last_name_record_8.wav: 768.6093121501472
# Distance between last_name_record_1.wav and last_name_record_9.wav: 630.5551667018608
# Distance between last_name_record_2.wav and last_name_record_3.wav: 1154.4322675659496
# Distance between last_name_record_2.wav and last_name_record_4.wav: 1001.7606243879563
# Distance between last_name_record_2.wav and last_name_record_5.wav: 346.7944869743005
# Distance between last_name_record_2.wav and last_name_record_6.wav: 487.15679693227867
# Distance between last_name_record_2.wav and last_name_record_7.wav: 576.6547373911017
# Distance between last_name_record_2.wav and last_name_record_8.wav: 653.4497229317421
# Distance between last_name_record_2.wav and last_name_record_9.wav: 548.4508116369307
# Distance between last_name_record_3.wav and last_name_record_4.wav: 463.0785204057611
# Distance between last_name_record_3.wav and last_name_record_5.wav: 991.8917465413906
# Distance between last_name_record_3.wav and last_name_record_6.wav: 738.9305878627638
# Distance between last_name_record_3.wav and last_name_record_7.wav: 1064.0079328454158
# Distance between last_name_record_3.wav and last_name_record_8.wav: 1300.4632712772218
# Distance between last_name_record_3.wav and last_name_record_9.wav: 925.9773145683339
# Distance between last_name_record_4.wav and last_name_record_5.wav: 804.883115748722
# Distance between last_name_record_4.wav and last_name_record_6.wav: 517.5453369324823
# Distance between last_name_record_4.wav and last_name_record_7.wav: 832.9113076364592
# Distance between last_name_record_4.wav and last_name_record_8.wav: 1073.483984594357
# Distance between last_name_record_4.wav and last_name_record_9.wav: 774.1763896644297
# Distance between last_name_record_5.wav and last_name_record_6.wav: 486.0793648038889
# Distance between last_name_record_5.wav and last_name_record_7.wav: 326.6699655357588
# Distance between last_name_record_5.wav and last_name_record_8.wav: 371.6978532119683
# Distance between last_name_record_5.wav and last_name_record_9.wav: 526.677785710026
# Distance between last_name_record_6.wav and last_name_record_7.wav: 370.01976658857893
# Distance between last_name_record_6.wav and last_name_record_8.wav: 545.8584602542032
# Distance between last_name_record_6.wav and last_name_record_9.wav: 405.92134878184334
# Distance between last_name_record_7.wav and last_name_record_8.wav: 553.6224457038552
# Distance between last_name_record_7.wav and last_name_record_9.wav: 361.49580156017873
# Distance between last_name_record_8.wav and last_name_record_9.wav: 474.83377604918314

# %%
for i in range(10):
    for j in range(10, 13):
        
        distance = calculate_dtw_distance(last_name_features_list[i], last_name_features_list[j])
        print(f"Distance between last_name_record_{i}.wav and last_name_record_{j}.wav: {distance}")
# Out:
# Distance between last_name_record_0.wav and last_name_record_10.wav: 579.3516725633235
# Distance between last_name_record_0.wav and last_name_record_11.wav: 630.6816887669411
# Distance between last_name_record_0.wav and last_name_record_12.wav: 585.0834433054988
# Distance between last_name_record_1.wav and last_name_record_10.wav: 727.0328585483512
# Distance between last_name_record_1.wav and last_name_record_11.wav: 653.3426723838566
# Distance between last_name_record_1.wav and last_name_record_12.wav: 716.8738009960143
# Distance between last_name_record_2.wav and last_name_record_10.wav: 618.0813723053725
# Distance between last_name_record_2.wav and last_name_record_11.wav: 509.949418686374
# Distance between last_name_record_2.wav and last_name_record_12.wav: 640.35240467322
# Distance between last_name_record_3.wav and last_name_record_10.wav: 1576.1627568461117
# Distance between last_name_record_3.wav and last_name_record_11.wav: 1472.1283028396283
# Distance between last_name_record_3.wav and last_name_record_12.wav: 1264.245986773647
# Distance between last_name_record_4.wav and last_name_record_10.wav: 1455.1045458029112
# Distance between last_name_record_4.wav and last_name_record_11.wav: 1328.53084022025
# Distance between last_name_record_4.wav and last_name_record_12.wav: 1099.0401251900767
# Distance between last_name_record_5.wav and last_name_record_10.wav: 721.4500136013885
# Distance between last_name_record_5.wav and last_name_record_11.wav: 529.8982115617619
# Distance between last_name_record_5.wav and last_name_record_12.wav: 612.1065613026803
# Distance between last_name_record_6.wav and last_name_record_10.wav: 829.8706140709401
# Distance between last_name_record_6.wav and last_name_record_11.wav: 771.4300027204008
# Distance between last_name_record_6.wav and last_name_record_12.wav: 538.1402103463333
# Distance between last_name_record_7.wav and last_name_record_10.wav: 939.0689948073414
# Distance between last_name_record_7.wav and last_name_record_11.wav: 542.9674301823688
# Distance between last_name_record_7.wav and last_name_record_12.wav: 388.5219137407694
# Distance between last_name_record_8.wav and last_name_record_10.wav: 503.34939486314397
# Distance between last_name_record_8.wav and last_name_record_11.wav: 507.7292246130746
# Distance between last_name_record_8.wav and last_name_record_12.wav: 379.8637076180821
# Distance between last_name_record_9.wav and last_name_record_10.wav: 698.3932245104897
# Distance between last_name_record_9.wav and last_name_record_11.wav: 811.6353433321692
# Distance between last_name_record_9.wav and last_name_record_12.wav: 518.0324459111343

# %%
last_name_features_list_mfccs = []
for i in range(13):
    y, sr = librosa.load(audio_files[i])
    y_trimmed, _ = librosa.effects.trim(y, top_db=20)
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13) 
    last_name_features_list_mfccs.append(mfccs)

# %%
for i in range(10):
    for j in range(i+1, 10):
        
        distance = calculate_dtw_distance(last_name_features_list_mfccs[i], last_name_features_list_mfccs[j])
        print(f"Distance between last_name_record_{i}.wav and last_name_record_{j}.wav: {distance}")
# Out:
# Distance between last_name_record_0.wav and last_name_record_1.wav: 7458.576320186257
# Distance between last_name_record_0.wav and last_name_record_2.wav: 5569.2559729367495
# Distance between last_name_record_0.wav and last_name_record_3.wav: 29728.180126667023
# Distance between last_name_record_0.wav and last_name_record_4.wav: 27166.327361673117
# Distance between last_name_record_0.wav and last_name_record_5.wav: 14079.613772649318
# Distance between last_name_record_0.wav and last_name_record_6.wav: 12402.630114592612
# Distance between last_name_record_0.wav and last_name_record_7.wav: 11918.904730342329
# Distance between last_name_record_0.wav and last_name_record_8.wav: 8798.049835391343
# Distance between last_name_record_0.wav and last_name_record_9.wav: 14733.49833379127
# Distance between last_name_record_1.wav and last_name_record_2.wav: 9005.926771432161
# Distance between last_name_record_1.wav and last_name_record_3.wav: 34695.81300459802
# Distance between last_name_record_1.wav and last_name_record_4.wav: 29918.273756459355
# Distance between last_name_record_1.wav and last_name_record_5.wav: 16330.806896362454
# Distance between last_name_record_1.wav and last_name_record_6.wav: 14721.115754880011
# Distance between last_name_record_1.wav and last_name_record_7.wav: 15585.399252332747
# Distance between last_name_record_1.wav and last_name_record_8.wav: 12060.794691234827
# Distance between last_name_record_1.wav and last_name_record_9.wav: 19278.546177441254
# Distance between last_name_record_2.wav and last_name_record_3.wav: 33629.62325270474
# Distance between last_name_record_2.wav and last_name_record_4.wav: 29383.666238620877
# Distance between last_name_record_2.wav and last_name_record_5.wav: 14198.44133689627
# Distance between last_name_record_2.wav and last_name_record_6.wav: 9726.331052653491
# Distance between last_name_record_2.wav and last_name_record_7.wav: 12415.866496495903
# Distance between last_name_record_2.wav and last_name_record_8.wav: 9445.634916462004
# Distance between last_name_record_2.wav and last_name_record_9.wav: 16715.805607413873
# Distance between last_name_record_3.wav and last_name_record_4.wav: 16866.54983341694
# Distance between last_name_record_3.wav and last_name_record_5.wav: 29734.848306465894
# Distance between last_name_record_3.wav and last_name_record_6.wav: 31008.008305363357
# Distance between last_name_record_3.wav and last_name_record_7.wav: 27539.478198073804
# Distance between last_name_record_3.wav and last_name_record_8.wav: 32926.59312646836
# Distance between last_name_record_3.wav and last_name_record_9.wav: 26079.918007349595
# Distance between last_name_record_4.wav and last_name_record_5.wav: 26866.24461420253
# Distance between last_name_record_4.wav and last_name_record_6.wav: 24843.46683280915
# Distance between last_name_record_4.wav and last_name_record_7.wav: 25908.357953719795
# Distance between last_name_record_4.wav and last_name_record_8.wav: 30742.913018874824
# Distance between last_name_record_4.wav and last_name_record_9.wav: 23437.114707535133
# Distance between last_name_record_5.wav and last_name_record_6.wav: 12658.260473679751
# Distance between last_name_record_5.wav and last_name_record_7.wav: 13321.444562029094
# Distance between last_name_record_5.wav and last_name_record_8.wav: 12305.491702843457
# Distance between last_name_record_5.wav and last_name_record_9.wav: 19064.285519031808
# Distance between last_name_record_6.wav and last_name_record_7.wav: 9194.902440816164
# Distance between last_name_record_6.wav and last_name_record_8.wav: 12148.543034404516
# Distance between last_name_record_6.wav and last_name_record_9.wav: 20624.68016196601
# Distance between last_name_record_7.wav and last_name_record_8.wav: 7995.468121886253
# Distance between last_name_record_7.wav and last_name_record_9.wav: 14667.596184162423
# Distance between last_name_record_8.wav and last_name_record_9.wav: 14977.093307254836

# %%
for i in range(10):
    for j in range(10, 13):
        
        distance = calculate_dtw_distance(last_name_features_list_mfccs[i], last_name_features_list_mfccs[j])
        print(f"Distance between last_name_record_{i}.wav and last_name_record_{j}.wav: {distance}")
# Out:
# Distance between last_name_record_0.wav and last_name_record_10.wav: 7614.6187072992325
# Distance between last_name_record_0.wav and last_name_record_11.wav: 9547.329936489463
# Distance between last_name_record_0.wav and last_name_record_12.wav: 9336.463336408138
# Distance between last_name_record_1.wav and last_name_record_10.wav: 10685.556361474097
# Distance between last_name_record_1.wav and last_name_record_11.wav: 12977.724519401789
# Distance between last_name_record_1.wav and last_name_record_12.wav: 11657.689775645733
# Distance between last_name_record_2.wav and last_name_record_10.wav: 6951.738241955638
# Distance between last_name_record_2.wav and last_name_record_11.wav: 10079.932273223996
# Distance between last_name_record_2.wav and last_name_record_12.wav: 10483.166275903583
# Distance between last_name_record_3.wav and last_name_record_10.wav: 34286.938518077135
# Distance between last_name_record_3.wav and last_name_record_11.wav: 35199.72918513417
# Distance between last_name_record_3.wav and last_name_record_12.wav: 32351.834181934595
# Distance between last_name_record_4.wav and last_name_record_10.wav: 31368.490908384323
# Distance between last_name_record_4.wav and last_name_record_11.wav: 33651.39348092675
# Distance between last_name_record_4.wav and last_name_record_12.wav: 29167.848255753517
# Distance between last_name_record_5.wav and last_name_record_10.wav: 22062.61525909975
# Distance between last_name_record_5.wav and last_name_record_11.wav: 18377.754611898214
# Distance between last_name_record_5.wav and last_name_record_12.wav: 9005.211014848202
# Distance between last_name_record_6.wav and last_name_record_10.wav: 16949.885937429965
# Distance between last_name_record_6.wav and last_name_record_11.wav: 16478.99711855501
# Distance between last_name_record_6.wav and last_name_record_12.wav: 11929.44736995548
# Distance between last_name_record_7.wav and last_name_record_10.wav: 15399.469479449093
# Distance between last_name_record_7.wav and last_name_record_11.wav: 11196.940894834697
# Distance between last_name_record_7.wav and last_name_record_12.wav: 9481.432754836977
# Distance between last_name_record_8.wav and last_name_record_10.wav: 11802.517115056515
# Distance between last_name_record_8.wav and last_name_record_11.wav: 7336.389063306153
# Distance between last_name_record_8.wav and last_name_record_12.wav: 6526.124386109412
# Distance between last_name_record_9.wav and last_name_record_10.wav: 16723.308946320787
# Distance between last_name_record_9.wav and last_name_record_11.wav: 16047.132115652785
# Distance between last_name_record_9.wav and last_name_record_12.wav: 13743.622511873022
